# %% [markdown]
# # FastText
# The idea is extracting syntax and morphology particular to each author.
#
# I'm using the first part of [this article](https://stackabuse.com/python-for-nlp-working-with-facebook-fasttext-library/).

# %%
# we get facebook's FastText
# !git clone https://github.com/facebookresearch/fastText.git
! pip install fastText/.
# ... and import it
import fasttext
# Out:
# fatal: destination path 'fastText' already exists and is not an empty directory.
# Processing ./fastText
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.9.1) (2.4.3)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.9.1) (42.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fasttext==0.9.1) (1.17.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.1-cp36-cp36m-linux_x86_64.whl size=2854366 sha256=b0d97fddb12cdbdd2a4b8aa05ff3a8d16100432e08287901d1d25ccd647c3956
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x85ozi0c/wheels/a1/9f/52/696ce6c5c46325e840c76614ee5051458c0df10306987e7443
# Successfully built fasttext
# Installing collected packages: fasttext
#   Found existing installation: fasttext 0.9.1
#     Uninstalling fasttext-0.9.1:
#       Successfully uninstalled fasttext-0.9.1
# Successfully installed fasttext-0.9.1

# %%
# we also use Gensim for convenience, so we get it
# !pip install --upgrade gensim
# ... and import it
from gensim.models.fasttext import FastText

# %%
# we now need the text. We get it from Kaggle -- feel free to use my API key :)
import os
os.environ['KAGGLE_USERNAME'] = "extremelydifficult" # username from the json file
os.environ['KAGGLE_KEY'] = "238120927f9705524c124fcbdb19b699" # key from the json file
# !kaggle competitions download -c spooky-author-identification
# !unzip \*.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# test.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  train.zip
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
#
# Archive:  test.zip
#
# Archive:  sample_submission.zip
#
# 3 archives were successfully processed.

# %%
# we now take everything into a dataframe
import pandas as pd
# get data from dataset
train = pd.read_csv('train.csv')
train.head
# Out:
# <bound method NDFrame.head of             id                                               text author
# 0      id26305  This process, however, afforded me no means of...    EAP
# 1      id17569  It never once occurred to me that the fumbling...    HPL
# 2      id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3      id27763  How lovely is spring As we looked from Windsor...    MWS
# 4      id12958  Finding nothing else, not even gold, the Super...    HPL
# ...        ...                                                ...    ...
# 19574  id17718  I could have fancied, while I looked at it, th...    EAP
# 19575  id08973  The lids clenched themselves together as if in...    EAP
# 19576  id05267  Mais il faut agir that is to say, a Frenchman ...    EAP
# 19577  id17513  For an item of news like this, it strikes us i...    EAP
# 19578  id00393  He laid a gnarled claw on my shoulder, and it ...    HPL
#
# [19579 rows x 3 columns]>

# %%
# we see that there's id, text, and author columns
print("Columns: ", train.columns)
# and that the most frequent author is EAP
import numpy as np
for author in np.unique(train['author']):
  print(str(author), len(train[train['author']==author]))
# the dataset is somewhat imbalanced.
# Out:
# Columns:  Index(['id', 'text', 'author'], dtype='object')
# EAP 7900
# HPL 5635
# MWS 6044

# %%
# we split into 3 corpora for training
eap = train[train['author']=='EAP']
hpl = train[train['author']=='HPL']
mws = train[train['author']=='MWS']

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Removing periods from honorifics and such [DONE]
# These need to be done by hand

# %%
import re

test_text = "Dr. John H. lived in the U. S. A. with  Mrs. H. for five years. . . He had lived in N.Y. before, at No. 7 Fleet St.. He was a good man."

test_text.replace("Dr.", "Dr")
test_text.replace("Mr.", "Mr")
test_text.replace("Mrs.", "Mrs")
test_text.replace("Esq.", "Esq")
test_text.replace("Messrs.", "Messrs")
# Out:
# 'Dr. John H. lived in the U. S. A. with  Mrs. H. for five years. . . He had lived in N.Y. before, at No. 7 Fleet St.. He was a good man.'

# %% [markdown]
# ## Removing Acronymns and one-letter abreviations [DONE]

# %%
[i for i in train["text"] if " : " in i][:10]
# Out:
# ['It was at : P.M., August , that poor Klenze went wholly mad.',
#  'About noon I encountered a suitable supply house far downtown, and at approximately : p.m. arrived at my boarding place with the necessary paraphernalia and two sturdy and intelligent mechanics.']

# %%
#remove dots from acronyms and one-letter abreviations
acronym = re.compile(r"(?<!\w)([A-Za-z])\.")
new_test_text = acronym.sub(r"\1", test_text)

# %%
new_test_text
# Out:
# 'Dr. John H lived in the U S A with  Mrs. H for five years. . . He had lived in NY before, at No. 7 Fleet St.. He was a good man.'

# %%
#remove spaces from separated acronyms
wierd_acronym = re.compile(r"([A-Z])\s(?=[A-Z])")
wierd_acronym.sub(r"\1", new_test_text)
# Out:
# 'Dr. John H lived in the USA with  Mrs. H for five years. . . He had lived in NY before, at No. 7 Fleet St.. He was a good man.'

# %% [markdown]
# ## We replace . . . with ellipses [DONE]

# %%
[i for i in train["text"] if ". ." in i][:10]
# Out:
# ["they never stopped swimmin' in an' aout o' the river from that cursed reef o' Satan an' more an' more attic winders got a boarded up, an' more an' more noises was heerd in haouses as wa'n't s'posed to hev nobody in 'em. . . .",
#  "all over the reef an' swimmin' up the harbour into the Manuxet. . . .",
#  "and one, who led the way, was clad in a ghoulishly humped black coat and striped trousers, and had a man's felt hat perched on the shapeless thing that answered for a head. . . .",
#  "An' the smell was awful, like what it is araound Wizard Whateley's ol' haouse. . .",
#  "all made o' squirmin' ropes . . .",
#  "Remember we're dealing with a hideous world in which we are practically helpless. . . .",
#  'Madness rides the star wind . . .',
#  'Mr. Maelzel, to be sure, is not very tall, but upon drawing near the machine, his head will be found at least eighteen inches below the head of the Turk, although the latter, it will be remembered, is in a sitting position. .',
#  "that face with the red eyes an' crinkly albino hair, an' no chin, like the Whateleys . . .",
#  "others'll worship with us at meetin' time, an' sarten haouses hez got to entertain guests . . ."]

# %%
fake_ellipsis = re.compile(r'(\. ){3,}')
print(fake_ellipsis.sub("\u2026 ", test_text))
# Out:
# Dr. John H. lived in the U. S. A. with  Mrs. H. for five years… He had lived in N.Y. before, at No. 7 Fleet St.. He was a good man.

# %% [markdown]
# ## Turn consecutive periods into one [DONE]

# %%
[i for i in train["text"] if ".." in i][:10]
[i for i in train["text"] if "I said I was distrustful of the Authenticity of Ossian" in i][:10]
# Out:
# ['When, to agree with him, I said I was distrustful of the Authenticity of Ossian\'s ms, Mr. Johnson said: "That, Sir, does not do your Understanding particular Credit; for what all the Town is sensible of, is no great Discovery for a Grub Street Critick to make.']

# %%
consecutiveperiods = re.compile(r'\.{2,}')
print(consecutiveperiods.sub('.', test_text))
# Out:
# Dr. John H. lived in the U. S. A. with  Mrs. H. for five years. . . He had lived in N.Y. before, at No. 7 Fleet St. He was a good man.

# %% [markdown]
# ## Final Preprocessing

# %%
# First idea is to do minimal preprocessing and adding punctuation as words
# The idea is that authors use punctuation distinctively.
# Maybe get rid of capitalization?

import re

from gensim.parsing.preprocessing import preprocess_string
from gensim.parsing.preprocessing import strip_tags
from gensim.parsing.preprocessing import strip_multiple_whitespaces


CUSTOM_FILTERS = [strip_multiple_whitespaces, strip_tags]
emdash= u"\u2014"
ellipsis = u"\u2026"
punctuation = list(set(',.:;\'()"?!-'))
punctuation.append(emdash)
punctuation.append(ellipsis)


def preprocess(text):
  """Things that we were able to find"""
  text = text.replace("Dr.", "Dr")
  text = text.replace("Mr.", "Mr")
  text = text.replace("Mrs.", "Mrs")
  text = text.replace("Esq.", "Esq")
  text = text.replace("Messrs.", "Messrs")
  acronym = re.compile(r"(?<!\w)([A-Za-z])\.")
  text = acronym.sub(r"\1", text)
  wierd_acronym = re.compile(r"([A-Z])\s(?=[A-Z])")
  text = wierd_acronym.sub(r"\1", text)
  fake_ellipsis = re.compile(r'(\. ){3,}')
  text = fake_ellipsis.sub("\u2026 ", text)
  consecutiveperiods = re.compile(r'\.{2,}')
  text = consecutiveperiods.sub('.', text)
  return text

def words_as_punctuation_preprocess(text):
    text = preprocess(text)
    text = text.replace("' ", " ' ")
    prods = set(text) & set(punctuation)
    if not prods:
        return text
    for sign in prods:
        text = text.replace(sign, ' {} '.format(sign) )
    text = " ".join(preprocess_string(text, CUSTOM_FILTERS)) #we still have the same problem
    # text = " ".join(fasttext.tokenize(text))
    # text = text.encode('utf-8').strip().decode("utf-8", "strict") #we had whitespace in EAP
    return text.lower()

 # from the documentation https://github.com/facebookresearch/fastText/tree/master/python#text-classification-model, this is expected behavior: 
 # "The newline character is used to delimit lines of text. In particular, the EOS token is appended to a line of text if a newline character is encountered."

# %%
all_corpus = pd.DataFrame([words_as_punctuation_preprocess(i) for i in train['text']], columns= ['text'])
[i for i in all_corpus["text"] if " mr " in i][:10]
# Out:
# ['matters had now assumed a really serious aspect , and i resolved to call at once upon my particular friend , mr theodore sinivate ; for i knew that here at least i should get something like definite information .',
#  'i suppose some astonishment was exhibited in my countenance , for mr kirwin hastened to say , " immediately upon your being taken ill , all the papers that were on your person were brought me , and i examined them that i might discover some trace by which i could send to your relations an account of your misfortune and illness .',
#  'sir , through our common friend , mr p , i have received your note of this evening .',
#  'long and earnestly did i continue the investigation : but the contemptible reward of my industry and perseverance proved to be only a set of false teeth , two pair of hips , an eye , and a bundle of billets doux from mr windenough to my wife .',
#  'when , to agree with him , i said i was distrustful of the authenticity of ossian \' s ms , mr johnson said : " that , sir , does not do your understanding particular credit ; for what all the town is sensible of , is no great discovery for a grub street critick to make .',
#  'to carry out his views , he solicited and obtained the patronage of sir everard bringhurst and mr osborne , two gentlemen well known for scientific acquirement , and especially for the interest they have exhibited in the progress of ærostation .',
#  'i have little to record , except the fact to me quite a surprising one that , at an elevation equal to that of cotopaxi , i experienced neither very intense cold , nor headache , nor difficulty of breathing ; neither , i find , did mr mason , nor mr holland , nor sir everard .',
#  'it was nearly dead calm when the voyagers first came in view of the coast , which was immediately recognized by both the seamen , and by mr osborne .',
#  "the writer professes to have translated his work from the english of one mr d ' avisson davidson ?",
#  'the patient , mr edward stapleton , had died , apparently of typhus fever , accompanied with some anomalous symptoms which had excited the curiosity of his medical attendants .']

# %%
words_as_punctuation_preprocess("this is an example. But…I shouldn't wait!")
# Out:
# "this is an example . but … i shouldn ' t wait !"

# %%
eap_corpus = pd.DataFrame([words_as_punctuation_preprocess(i) for i in eap['text']], columns= ['text'])
hpl_corpus = pd.DataFrame([words_as_punctuation_preprocess(i) for i in hpl['text']], columns= ['text'])
mws_corpus = pd.DataFrame([words_as_punctuation_preprocess(i) for i in mws['text']], columns= ['text'])

# %%
# embedding_size = 60
# window_size = 40
# min_word = 5
# down_sampling = 1e-2

from gensim.models.fasttext import FastText

# %%
from io import StringIO
import csv
from sklearn.utils import shuffle

# EAP
eap_corpus.to_csv(r'/content/eap_corpus.txt', index=False, sep=' ', header=False, quoting=csv.QUOTE_NONE, quotechar="", escapechar=" ")
eap_ft_model = fasttext.train_unsupervised('eap_corpus.txt')
eap_ft_model.save_model('eap_ft_model.bin')

# HPL
hpl_corpus.to_csv(r'/content/hpl_corpus.txt', index=False, sep=' ', header=False, quoting=csv.QUOTE_NONE, quotechar="", escapechar=" ")
hpl_ft_model = fasttext.train_unsupervised('hpl_corpus.txt')
hpl_ft_model.save_model('hpl_ft_model.bin')
# MWS
mws_corpus.to_csv(r'/content/mws_corpus.txt', index=False, sep=' ', header=False, quoting=csv.QUOTE_NONE, quotechar="", escapechar=" ")
mws_ft_model = fasttext.train_unsupervised('mws_corpus.txt')
mws_ft_model.save_model('mws_ft_model.bin')

# %% [markdown]
# # Analysis
# In all authors, we see marked difference in the use of punctuation. Clusters are clear via TSNE or PCA but the frequency of nearest neighbors is very different.

# %% [markdown]
# ## MWS

# %%
from sklearn.manifold import TSNE

# %%
word_treshold = 1000
just_keep_major_punct = True


from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

ft_mws_model = FastText.load_fasttext_format('mws_ft_model.bin')

# first we check the punctuation assertion: which tokens are the most similar to exisiting punctuation?

for i in punctuation:
  print(i + ' exists: ' +str(i in ft_mws_model.wv.vocab))
# and remove the ones that don't since we need at least one n-gram with it for comparison

punctuation_in_mws = [i for i in punctuation if i in ft_mws_model.wv.vocab]

if just_keep_major_punct:
  punctuation_in_mws.remove("'")
  try:
    punctuation_in_mws.remove('…')
  except:
    pass 
  punctuation_in_mws.remove(':')
  punctuation_in_mws.remove('?')
  punctuation_in_mws.remove('"')

semantically_similar_words = {words: [item[0] for item in ft_mws_model.wv.most_similar([words], topn=word_treshold)] for words in punctuation_in_mws}
for k,v in semantically_similar_words.items():
    print(k+":"+str(v))
all_similar_words = sum([[k] + v for k, v in semantically_similar_words.items()], [])
frequency_of_words = [ft_mws_model.wv.vocab[i].count for i in all_similar_words]
#frequency_of_words = [i if i<100 else 100 for i in frequency_of_words ]

print(all_similar_words)
print(type(all_similar_words))
print(len(all_similar_words))

word_vectors = ft_mws_model.wv[all_similar_words]

pca = PCA(n_components=2)

p_comps = pca.fit_transform(word_vectors)
#p_comps = TSNE(n_components=2, perplexity=5).fit_transform(word_vectors)

word_names = all_similar_words
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
# ; exists: True
# , exists: True
# . exists: True
# " exists: True
# ! exists: False
# : exists: True
# ? exists: True
# ( exists: False
# - exists: False
# ' exists: True
# ) exists: False
# — exists: False
# … exists: False
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:2377: RuntimeWarning: invalid value encountered in true_divide
#   return (m / dist).astype(REAL)
# ;:['sweet', 'heart', 'till', 'again', 'gods', 'livid', 'already', 'weep', 'wave', 'younger', 'glow', 'dog', 'thanks', 'still', 'youthful', 'clear', 'soothe', 'move', 'dread', 'third', 'against', 'pillow', 'shape', 'free', 'put', 'lively', 'lives', 'youth', 'sweetest', 'far', ',', 'beggar', 'wild', 'alarm', 'lot', 'dull', 'shaken', 'sword', 'thrust', 'threat', 'faith', 'dreams', 'brave', 'shrink', 'find', 'triumph', 'lonely', 'tone', 'sir', 'june', 'last', 'veil', 'level', 'evelyn', 'cast', 'bleak', 'certain', 'glad', 'shrieks', 'drink', 'agony', 'silly', 'theories', 'whisper', 'girl', 'mien', 'words', 'poet', 'crew', 'mute', 'frankenstein', 'wildly', 'voice', 'heroism', 'where', 'scream', 'keep', 'christian', 'filthy', 'blow', 'aim', 'angrily', 'double', 'help', 'strive', 'art', 'afraid', 'escape', 'laid', 'becomes', 'kishan', 'willingly', 'feeble', 'mankind', 'marry', 'doubly', 'beyond', 'sink', 'dwelt', 'ourselves', 'however', 'certainly', 'altogether', 'shake', 'hardly', 'cruelty', 'havoc', 'rise', 'alone', 'little', 'tearful', 'sacrifice', 'blast', 'peaceful', 'husband', 'thirst', 'earthly', 'yes', 'soothing', 'uncle', 'candidate', 'year', 'longer', 'crept', 'swept', 'sheep', 'dogs', 'beat', 'noisy', 'get', 'join', 'heartless', 'laugh', 'hollow', 'bare', 'bid', 'weak', 'brief', 'heat', 'noble', 'choice', 'begin', 'terror', 'globe', 'demand', 'most', 'untill', 'earthquake', 'hateful', 'awake', 'fuel', 'extasy', 'arise', 'met', 'sail', 'feet', 'hitherto', 'ago', 'fail', 'further', 'away', 'medicine', 'fit', 'hearts', 'ryland', 'as', 'sorrow', 'has', 'behold', 'mr', 'welfare', 'motive', 'pay', 'lead', 'hill', 'twelve', 'earnestly', 'hellish', 'type', 'enquiries', 'choose', 'cradle', 'wherefore', 'surprise', 'gold', 'crimes', 'low', 'seems', 'wake', 'joyous', 'outcast', 'write', 'morrow', 'childhood', 'frenzy', 'yesterday', 'irreparable', 'mild', 'else', 'aware', 'kirwin', 'explain', 'glare', 'uncertain', 'tall', 'fall', 'suppose', 'show', 'duties', 'drove', 'least', 'methinks', 'avoid', 'domestic', 'bitterly', 'henry', 'follow', 'bind', 'chill', 'decide', 'falsehood', 'thing', 'poor', 'mirror', 'earl', 'owe', 'fill', 'overcome', 'akin', 'talk', 'shout', 'purpose', 'example', 'seem', 'calm', 'therefore', 'shudder', 'verney', 'safe', 'makes', 'laughter', 'child', 'hot', 'mischief', 'fellow', 'berries', 'accept', 'shelter', 'nurse', 'except', 'even', 'mean', 'fulfil', 'europe', 'forget', 'link', 'leads', 'toil', 'wait', 'alps', 'base', 'learnt', 'fortunately', 'line', 'foolish', 'disgust', 'heretofore', 'feels', 'sad', 'grave', 'fearful', 'truly', 'fact', 'tyranny', 'cousin', 'bend', 'offer', 'bliss', 'shine', 'captain', 'extinct', 'demeanour', 'truth', 'avail', 'one', 'guilty', 'assist', 'impossible', 'pursuit', 'cherish', 'list', 'malice', 'blind', 'shone', 'very', 'brothers', 'ten', 'grief', 'esteem', 'raise', 'hand', 'dreadful', 'within', 'man', 'satisfy', 'applause', 'volume', 'angel', 'harvest', 'author', 'written', 'irish', 'sustain', 'uneasy', 'glory', 'given', 'period', 'possible', 'unite', 'praise', 'unlike', 'undertake', 'causes', 'venerable', 'kindly', 'deck', 'enemies', 'merely', 'only', 'nearer', 'inquiries', 'agonies', 'strange', 'comfort', 'utterly', 'terrible', 'afford', 'mate', 'eat', 'idris', 'artist', 'cabin', 'superior', 'murmur', 'survive', 'terrific', 'worst', 'origin', 'sweetness', 'pursue', 'foot', 'due', 'safie', 'justice', 'honour', 'nerve', 'sorry', 'sympathies', 'defeat', 'notice', 'careful', 'oak', 'breathless', 'dream', 'break', 'daughter', 'chief', 'hardship', 'envy', 'manifest', 'perform', 'pilot', 'deliverer', 'heard', 'surely', 'reproach', 'frank', 'danger', 'excite', 'exercise', 'nearest', 'truce', 'wrote', 'add', 'pulse', 'support', 'quit', 'virtuous', 'evadne', 'meet', 'but', 'without', 'vivid', 'driven', 'deliver', 'alike', 'failure', 'prayer', 'benefit', 'wit', 'delirium', 'caught', 'pause', 'appear', 'lover', 'fellows', 'five', 'joy', 'weather', 'belong', 'species', 'sincerely', 'somethin ...
# ,:['where', ';', 'sweet', 'when', 'ryland', 'altogether', 'near', 'hand', 'earl', 'dog', 'lonely', 'further', 'silly', 'clear', 'younger', 'girl', 'weather', 'weep', 'sad', 'has', 'free', 'husband', 'ago', 'heroism', 'year', 'brothers', 'shaken', 'little', 'whisper', 'lively', 'gold', 'crew', 'nearer', 'laid', 'shout', 'livid', 'already', 'hardly', 'here', 'soothe', 'swept', 'move', 'as', 'lot', 'tone', 'wake', 'wildly', 'laugh', 'dwelt', 'wave', 'safie', 'sheep', 'youth', 'dread', 'sir', 'youthful', 'heard', 'again', 'gods', 'christian', 'hereafter', 'wait', 'glad', 'shrieks', 'shone', 'marry', 'raymond', 'dogs', 'angrily', 'till', 'shelter', 'sail', 'alarm', 'afraid', 'most', 'level', 'man', 'veil', 'evelyn', 'art', 'heat', 'mien', 'third', 'june', 'beggar', 'kirwin', 'beyond', 'wholly', 'havoc', 'against', 'however', 'laughter', 'sword', 'far', 'wild', 'wherefore', 'he', 'hollow', 'behold', 'heretofore', 'doubly', 'faith', 'fly', 'pay', 'sweetest', 'fuel', 'mankind', 'hot', 'childhood', 'kishan', 'leads', 'shepherd', 'threat', 'poet', 'mute', 'talk', 'given', 'follow', 'last', 'volume', 'belong', 'low', 'agony', 'merely', 'quite', 'triumph', 'put', 'earthly', 'thanks', 'feet', 'daughter', 'outcast', 'mr', 'met', 'candidate', 'cradle', 'find', 'driven', 'willingly', 'sink', 'hard', 'lover', 'mild', 'murmur', 'hitherto', 'soothing', 'glow', 'written', 'noisy', 'whilst', 'elder', 'blast', 'dreams', 'heart', 'tearful', 'still', 'shrink', 'quit', 'she', 'awake', 'longer', 'akin', 'lives', 'sank', 'join', 'pillow', 'loathsome', 'blow', 'yes', 'henry', 'overcome', 'bind', 'certainly', 'earthquake', 'fail', 'toil', 'cabin', 'irreparable', 'news', 'extasy', 'avoid', 'joyous', 'keep', 'frankenstein', 'frenzy', 'domestic', 'foot', 'ten', 'men', 'yesterday', 'crept', 'globe', 'oak', 'feeble', 'alps', 'type', 'falsehood', 'vivid', 'o', 'drink', 'poor', 'alone', 'certain', 'dull', 'choose', 'northern', 'europe', 'double', 'door', 'agrippa', 'author', 'thing', 'begin', 'gather', 'thrust', 'something', 'safe', 'seems', 'hearts', 'uneasy', 'hill', 'bleak', 'uncle', 'beat', 'sacrifice', 'escape', 'avail', 'theories', 'explain', 'becomes', 'aim', 'older', 'master', 'earnestly', 'part', 'get', 'moritz', 'shape', 'awaken', 'demand', 'monster', 'utterly', 'blind', 'weak', 'hero', 'origin', 'deck', 'bitterly', 'sit', 'break', 'medicine', 'frank', 'letters', 'unlike', 'mirror', 'cast', 'artist', 'together', 'scream', 'lead', 'especially', 'burthen', 'lately', 'rome', 'danger', 'cousin', 'only', 'england', 'period', 'harvest', 'example', 'bid', 'prayer', 'offer', 'mean', 'equally', 'observe', 'weary', 'write', 'terrific', 'fearful', 'pilot', 'cruelty', 'disgust', 'cheer', 'arise', 'therefore', 'shudder', 'hardship', 'hateful', 'accept', 'then', 'motive', 'orphan', 'deliverer', 'drama', 'help', 'strive', 'set', 'verney', 'fellows', 'due', 'peculiar', 'venerable', 'echo', 'idris', 'skin', 'hardships', 'irksome', 'torpor', 'child', 'tyranny', 'twelve', 'owe', 'surely', 'perdita', 'alike', 'afford', 'captain', 'untill', 'learnt', 'decide', 'school', 'pursuit', 'shut', 'manifest', 'reproach', 'visitor', 'quiet', 'vagabond', 'surprise', 'brave', 'brief', 'others', 'fortunately', 'strangely', 'second', 'idol', 'shake', 'voice', 'ambassador', 'hasten', 'filthy', 'fact', 'enquiries', 'sustain', 'asia', 'satisfy', 'away', 'thick', 'pursue', 'makes', 'children', 'paper', 'inquiries', 'ardour', 'dreadful', 'perform', 'noble', 'rise', 'sharp', 'awe', 'flesh', 'popular', 'milk', 'husbands', 'sails', 'demeanour', 'judge', 'drag', 'held', 'safety', 'childish', 'extremely', 'ourselves', 'show', 'supply', 'berries', 'uncertain', 'superior', 'snow', 'purpose', 'suppose', 'taken', 'combat', 'bliss', 'order', 'speedily', 'shine', 'peaceful', 'except', 'foolish', 'model', 'esteem', 'truth', 'forget', 'asylum', 'boy', 'september', 'thirst', 'mere', 'least', 'fit', 'fairy', 'fervour', 'terror', 'sincerely', 'wife', 'hurt', 'october', 'reward', 'eat', 'malice', 'remark', ' ...
# .:['nature', 'future', 'opinion', 'instructions', 'dominion', 'favour', 'poison', 'influence', 'fashion', 'miniature', 'intercourse', 'visions', 'maturity', 'spirit', 'an', 'pity', 'circumstances', 'exertions', 'noon', 'pour', 'aspirations', 'activity', 'mind', 'motionless', 'french', 'native', 'world', 'point', 'functions', 'account', 'defence', 'humanity', 'annihilation', 'virtues', 'humour', 'human', 'abhorrence', 'circumstance', 'inheritance', 'picture', 'indulgence', 'excellence', 'tortures', 'insanity', 'science', 'qualities', 'try', 'audience', 'corruption', 'philosophy', 'succour', 'proportions', 'port', 'induce', 'recollections', 'impatience', 'treasure', 'suspicion', 'eternity', 'azure', 'stranger', 'hopes', 'seclusion', 'tempest', 'patience', 'measure', 'angels', 'thence', 'us', 'wonderful', 'change', 'vanity', 'idea', 'superiority', 'inspire', 'discourse', 'malignity', 'pleasure', 'gratitude', 'occasion', 'worth', 'descend', 'mansion', 'prudence', 'contagion', 'magnificence', 'gesture', 'virtue', 'ties', 'degradation', 'failure', 'rapture', 'visionary', 'beings', 'history', 'admit', 'evils', 'immortal', 'chaise', 'calamity', 'posterity', 'superstition', 'virtuous', 'hence', 'our', 'centre', 'faint', 'milk', 'flies', 'admire', 'favourable', 'sort', 'favourite', 'injury', 'sorrows', 'transitory', 'capable', 'woe', 'comparison', 'common', 'estate', 'revolution', 'submission', 'fulfilment', 'aspect', 'spirits', 'court', 'agonies', 'anger', 'species', 'wore', 'deformity', 'memory', 'fortitude', 'voluntary', 'ardour', 'inanimate', 'means', 'incapable', 'essence', 'angelic', 'depth', 'understand', 'liberty', 'worldly', 'determination', 'universe', 'circle', 'encourage', 'families', 'environs', 'execution', 'memories', 'sufficient', 'complacency', 'career', 'under', 'accents', 'infinite', 'glory', 'contain', 'merits', 'submit', 'pilot', 'break', 'communication', 'fairy', 'civilization', 'instinct', 'apprehension', 'inn', 'banish', 'purposes', 'convalescence', 'famine', 'fact', 'eternal', 'naturally', 'exception', 'inquiries', 'eloquent', 'universal', 'constantinople', 'daemon', 'mixture', 'effects', 'tranquil', 'desirous', 'propose', 'strangely', 'service', 'procure', 'sorrowful', 'sympathizing', 'ideas', 'imperfect', 'secrets', 'contemplation', 'soul', 'relatives', 'decision', 'reflections', 'frail', 'tranquillity', 'fervour', 'soil', 'fancies', 'symptoms', 'benefit', 'contemplate', 'familiar', 'persons', 'artist', 'capacity', 'dignity', 'absence', 'chasm', 'dwellings', 'opportunity', 'imitate', 'great', 'blessings', 'temper', 'angry', 'military', 'complaints', 'falsehood', 'prosperity', 'courage', 'celestial', 'secure', 'object', 'religion', 'vengeance', 'truth', 'enchain', 'breathless', 'guests', 'worse', 'woodville', 'presumption', 'companions', 'fade', 'divinity', 'causes', 'popular', 'orphan', 'university', 'both', 'childish', 'amiable', 'precious', 'term', 'cheerfulness', 'sorry', 'strange', 'delicate', 'english', 'pulse', 'eton', 'lifeless', 'malice', 'northern', 'impulse', 'owe', 'obedience', 'instead', 'chief', 'deserts', 'ordinary', 'protectorate', 'greater', 'easy', 'magistrate', 'features', 'disease', 'adversary', 'evidence', 'prejudices', 'frost', 'safety', 'joyous', 'west', 'certainty', 'desires', 'image', 'ineffectual', 'source', 'guardianship', 'example', 'paradise', 'probable', 'fiendish', 'infancy', 'metropolis', 'consummation', 'blind', 'multitude', 'protectors', 'men', 'manifest', 'wife', 'disorder', 'recollection', 'property', 'whole', 'fallen', 'excellent', 'life', 'efforts', 'hurt', 'aside', 'exile', 'tyranny', 'cares', 'husbands', 'authority', 'enthusiasm', 'series', 'worst', 'fulfil', 'ambassador', 'fine', 'ascend', 'pain', 'mechanism', 'virulence', 'duty', 'due', 'expectation', 'line', 'chapter', 'mystery', 'worn', 'population', 'fond', 'physiognomy', 'lustre', 'depths', 'vision', 'explanation', 'tameless', 'enemies', 'fiend', 'eloquence', 'delirium', 'system', 'melody', 'ecstasy', 'ensure', 'soo ...
# [';', 'sweet', 'heart', 'till', 'again', 'gods', 'livid', 'already', 'weep', 'wave', 'younger', 'glow', 'dog', 'thanks', 'still', 'youthful', 'clear', 'soothe', 'move', 'dread', 'third', 'against', 'pillow', 'shape', 'free', 'put', 'lively', 'lives', 'youth', 'sweetest', 'far', ',', 'beggar', 'wild', 'alarm', 'lot', 'dull', 'shaken', 'sword', 'thrust', 'threat', 'faith', 'dreams', 'brave', 'shrink', 'find', 'triumph', 'lonely', 'tone', 'sir', 'june', 'last', 'veil', 'level', 'evelyn', 'cast', 'bleak', 'certain', 'glad', 'shrieks', 'drink', 'agony', 'silly', 'theories', 'whisper', 'girl', 'mien', 'words', 'poet', 'crew', 'mute', 'frankenstein', 'wildly', 'voice', 'heroism', 'where', 'scream', 'keep', 'christian', 'filthy', 'blow', 'aim', 'angrily', 'double', 'help', 'strive', 'art', 'afraid', 'escape', 'laid', 'becomes', 'kishan', 'willingly', 'feeble', 'mankind', 'marry', 'doubly', 'beyond', 'sink', 'dwelt', 'ourselves', 'however', 'certainly', 'altogether', 'shake', 'hardly', 'cruelty', 'havoc', 'rise', 'alone', 'little', 'tearful', 'sacrifice', 'blast', 'peaceful', 'husband', 'thirst', 'earthly', 'yes', 'soothing', 'uncle', 'candidate', 'year', 'longer', 'crept', 'swept', 'sheep', 'dogs', 'beat', 'noisy', 'get', 'join', 'heartless', 'laugh', 'hollow', 'bare', 'bid', 'weak', 'brief', 'heat', 'noble', 'choice', 'begin', 'terror', 'globe', 'demand', 'most', 'untill', 'earthquake', 'hateful', 'awake', 'fuel', 'extasy', 'arise', 'met', 'sail', 'feet', 'hitherto', 'ago', 'fail', 'further', 'away', 'medicine', 'fit', 'hearts', 'ryland', 'as', 'sorrow', 'has', 'behold', 'mr', 'welfare', 'motive', 'pay', 'lead', 'hill', 'twelve', 'earnestly', 'hellish', 'type', 'enquiries', 'choose', 'cradle', 'wherefore', 'surprise', 'gold', 'crimes', 'low', 'seems', 'wake', 'joyous', 'outcast', 'write', 'morrow', 'childhood', 'frenzy', 'yesterday', 'irreparable', 'mild', 'else', 'aware', 'kirwin', 'explain', 'glare', 'uncertain', 'tall', 'fall', 'suppose', 'show', 'duties', 'drove', 'least', 'methinks', 'avoid', 'domestic', 'bitterly', 'henry', 'follow', 'bind', 'chill', 'decide', 'falsehood', 'thing', 'poor', 'mirror', 'earl', 'owe', 'fill', 'overcome', 'akin', 'talk', 'shout', 'purpose', 'example', 'seem', 'calm', 'therefore', 'shudder', 'verney', 'safe', 'makes', 'laughter', 'child', 'hot', 'mischief', 'fellow', 'berries', 'accept', 'shelter', 'nurse', 'except', 'even', 'mean', 'fulfil', 'europe', 'forget', 'link', 'leads', 'toil', 'wait', 'alps', 'base', 'learnt', 'fortunately', 'line', 'foolish', 'disgust', 'heretofore', 'feels', 'sad', 'grave', 'fearful', 'truly', 'fact', 'tyranny', 'cousin', 'bend', 'offer', 'bliss', 'shine', 'captain', 'extinct', 'demeanour', 'truth', 'avail', 'one', 'guilty', 'assist', 'impossible', 'pursuit', 'cherish', 'list', 'malice', 'blind', 'shone', 'very', 'brothers', 'ten', 'grief', 'esteem', 'raise', 'hand', 'dreadful', 'within', 'man', 'satisfy', 'applause', 'volume', 'angel', 'harvest', 'author', 'written', 'irish', 'sustain', 'uneasy', 'glory', 'given', 'period', 'possible', 'unite', 'praise', 'unlike', 'undertake', 'causes', 'venerable', 'kindly', 'deck', 'enemies', 'merely', 'only', 'nearer', 'inquiries', 'agonies', 'strange', 'comfort', 'utterly', 'terrible', 'afford', 'mate', 'eat', 'idris', 'artist', 'cabin', 'superior', 'murmur', 'survive', 'terrific', 'worst', 'origin', 'sweetness', 'pursue', 'foot', 'due', 'safie', 'justice', 'honour', 'nerve', 'sorry', 'sympathies', 'defeat', 'notice', 'careful', 'oak', 'breathless', 'dream', 'break', 'daughter', 'chief', 'hardship', 'envy', 'manifest', 'perform', 'pilot', 'deliverer', 'heard', 'surely', 'reproach', 'frank', 'danger', 'excite', 'exercise', 'nearest', 'truce', 'wrote', 'add', 'pulse', 'support', 'quit', 'virtuous', 'evadne', 'meet', 'but', 'without', 'vivid', 'driven', 'deliver', 'alike', 'failure', 'prayer', 'benefit', 'wit', 'delirium', 'caught', 'pause', 'appear', 'lover', 'fellows', 'five', 'joy', 'weather', 'belong', 'species', 'sincerely', 'somet ...
# <class 'list'>
# 3003

# %%
mycolors = [i-i%(word_treshold+1) for i in range(len(all_similar_words))]
mycolors = ['red' if i == 0 else 'cyan' if i==1001 else 'green' for i in mycolors]
plt.figure(figsize=(20, 5))
plt.title('MWS punctuation clusters')
plt.scatter(p_comps[:, 0], p_comps[:, 1], c=mycolors,  s = frequency_of_words, alpha=0.4)

for word_names, x, y in zip(word_names, p_comps[:, 0], p_comps[:, 1]):
  if word_names in punctuation_in_mws:
     plt.annotate(word_names, xy=(x+0.06, y+0.03), xytext=(0, 0), textcoords='offset points', size = 50, bbox=dict(facecolor='None', edgecolor='black'))
plt.show()

# %% [markdown]
# ## EAP

# %%
punctuation_in_eap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-ee368a771814> in <module>()
# ----> 1 punctuation_in_eap
#
# NameError: name 'punctuation_in_eap' is not defined

# %%
word_treshold = 1000
just_keep_major_punct = True


eap_ft_model = FastText.load_fasttext_format('eap_ft_model.bin')

# first we check the punctuation assertion: which tokens are the most similar to exisiting punctuation?

for i in punctuation:
  print(i + ' exists: ' +str(i in eap_ft_model.wv.vocab))
# and remove the ones that don't since we need at least one n-gram with it for comparison
punctuation_in_eap = [i for i in punctuation if i in eap_ft_model.wv.vocab]

if just_keep_major_punct:
  punctuation_in_eap.remove("'")
  try:
    punctuation_in_eap.remove('…')
  except:
    pass 
  punctuation_in_eap.remove(':')
  punctuation_in_eap.remove('?')
  punctuation_in_eap.remove('"')

semantically_similar_words = {words: [item[0] for item in eap_ft_model.wv.most_similar([words], topn=word_treshold)] for words in punctuation_in_eap}
for k,v in semantically_similar_words.items():
    print(k+":"+str(v))
all_similar_words = sum([[k] + v for k, v in semantically_similar_words.items()], [])
frequency_of_words = [eap_ft_model.wv.vocab[i].count for i in all_similar_words]
#frequency_of_words = [i if i<100 else 100 for i in frequency_of_words ]



print(all_similar_words)
print(type(all_similar_words))
print(len(all_similar_words))

word_vectors = eap_ft_model.wv[all_similar_words]

pca = PCA(n_components=2)

p_comps = pca.fit_transform(word_vectors)
#p_comps = TSNE(n_components=2, perplexity=100).fit_transform(word_vectors)

word_names = all_similar_words

# plt.figure(figsize=(18, 10))
# plt.scatter(p_comps[:, 0], p_comps[:, 1], c=[i-i%(word_treshold+1) for i in range(len(all_similar_words))], cmap='Set1', s = frequency_of_words, alpha=1)

# for word_names, x, y in zip(word_names, p_comps[:, 0], p_comps[:, 1]):
#   if word_names in punctuation_in_eap:
#      plt.annotate(word_names, xy=(x+0.06, y+0.03), xytext=(0, 0), textcoords='offset points', size = 20, bbox=dict(facecolor='None', edgecolor='black'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
#   """
# ; exists: True
# , exists: True
# . exists: True
# " exists: True
# ! exists: False
# : exists: True
# ? exists: True
# ( exists: False
# - exists: False
# ' exists: True
# ) exists: False
# — exists: False
# … exists: False
# ;:['sleep', 'freedom', 'stroke', 'chantilly', 'fearfully', 'dreadful', 'taste', 'footstep', 'glass', 'stiff', 'swept', 'vague', 'awful', 'palazzo', 'unquiet', 'dreamy', 'betook', 'unto', 'finger', 'gulf', 'beheld', 'screw', 'shriek', 'abruptly', 'slept', 'shrank', 'stupor', 'nostrils', 'burthen', 'whisper', 'seldom', 'burst', 'shrieks', 'brief', 'seize', 'raise', 'thoroughly', 'painful', 'blind', 'earnestly', 'stir', 'footsteps', 'shrill', 'shown', 'pair', 'dream', 'reward', 'wheels', 'muslin', 'risk', 'waker', 'lot', 'heels', 'shone', 'clew', 'childish', 'visit', 'hurriedly', 'quietly', 'whiskers', 'wherein', 'rash', 'razor', 'chief', 'jaws', 'pendulum', 'wept', 'built', 'pipe', 'task', 'gaze', 'sash', 'simultaneously', 'strip', 'lofoden', 'bas', 'kept', 'wealth', 'barrel', 'behavior', 'brilliancy', 'strongly', 'female', 'melody', 'casks', 'dreams', 'volume', 'sofa', 'freely', 'murmur', 'travelling', 'field', 'eleonora', 'calls', 'brink', 'bold', 'oak', 'blew', 'tomb', 'rigid', 'wisdom', 'diana', 'break', 'parlor', 'victim', 'fearful', 'leaden', 'law', 'scrutiny', 'zaire', 'burn', 'plunge', 'safely', 'deeply', 'screams', 'pain', 'bolt', 'ruin', 'canvas', 'elbow', 'ligeia', 'loathsome', 'fabric', 'chiefly', 'daily', 'avenue', 'search', 'july', 'shop', 'satellite', 'hitherto', 'tarpaulin', 'staircase', 'eyelids', 'whirlpool', 'grim', 'among', 'foam', 'paintings', 'hurricane', 'cabin', 'fairy', 'forbear', 'tone', 'oxford', 'eagerly', 'chimney', 'firmly', 'amid', 'louder', 'lovely', 'flew', 'lungs', 'dwelt', 'parallel', 'helseggen', 'solid', 'secret', 'sorrow', 'ocean', 'echo', 'cape', 'chagrin', 'luminous', 'rat', 'everywhere', 'stronger', 'thorough', 'deadly', 'tore', 'strange', 'singularly', 'metzengerstein', 'glare', 'dilemma', 'tapestry', 'bedloe', 'gorgeous', 'livid', 'blush', 'cat', 'mud', 'across', 'glad', 'crew', 'song', 'seas', 'ms', 'pallid', 'gad', 'brute', 'class', 'scythe', 'laws', 'harmony', 'grin', 'knife', 'pockets', 'castle', 'buckle', 'vessel', 'barrière', 'bore', 'margin', 'church', 'strong', 'cross', 'wave', 'berlifitzing', 'somewhere', 'brilliant', 'enjoy', 'vehicle', 'flesh', 'stage', 'shield', 'satin', 'child', 'alarm', 'basket', 'passage', 'likely', 'bulk', 'cabinet', 'lover', 'coat', 'wrath', 'heir', 'endeavors', 'scrutinized', 'skin', 'pallor', 'tongues', 'decay', 'vulgar', 'lunar', 'scrutinizing', 'favorite', 'creditors', 'frivolous', 'ourang', 'cask', 'chicken', 'arisen', 'fullest', 'shudder', 'depends', 'hereditary', 'moreover', 'enclosure', 'drunk', 'strangely', 'singular', 'wicker', 'emperor', 'glimpse', 'books', 'fairly', 'abyss', 'tube', 'visage', 'waist', 'hurry', 'pfaall', 'eustache', 'views', 'wherever', 'still', 'deposit', 'scrupulous', 'shake', 'melancholy', 'change', 'egypt', 'rare', 'hearts', 'inquiries', 'graceful', 'america', 'europe', 'gay', 'illimitable', 'slope', 'ström', 'carry', 'schools', 'grotesque', 'worn', 'maiden', 'orange', 'scrap', 'yells', 'tumultuous', 'behold', 'becoming', 'vain', 'warrant', 'solitude', 'lie', 'fierce', 'health', 'hesitate', 'clearly', 'drop', 'radiant', 'sweep', 'aloud', 'assuming', 'summit', 'epiphanes', 'dull', 'without', 'listen', 'george', 'smoke', 'customs', 'aside', 'list', 'vows', 'obtain', 'wig', 'rub', 'antennæ', 'pompey', 'opium', 'partook', 'horse', 'guesses', 'blows', 'was', 'grave', 'painting', 'loss', 'parisian', 'crime', 'sweeps', 'sad', 'epoch', 'vessels', 'shook', 'sockets', 'exquisite', 'lapse', 'longest', 'uneasy', 'philosophy', 'usher', 'manoeuvre', 'perpendicularly', 'bank', 'safe', 'empire', 'holy', 'salt', 'scratching', 'saw', 'ruffians', 'blackwood', 'granite', 'angry', 'marriage', 'luxury', 'axioms', 'papers', 'dismay', 'tarn', 'grow', 'where', 'penny', 'spot', 'set', 'tenant', 'also', 'verses', 'axis', 'accompanied', 'therein', 'valet', 'borough', 'banks', 'sovereign', 'steady', 'guide', 'shot', 'behind', 'gendarme', 'rudder', 'hereafter', 'accounting', 'music', 'bricks', 'awake', 'fresh', 'newspapers', 'dawn', 'symptoms', 'passa ...
# ,:['willing', 'travelling', 'writing', 'calling', 'scratching', 'following', 'assuming', 'painting', 'searching', 'speaking', 'becoming', 'strong', 'keeping', 'berlifitzing', 'wit', 'borough', 'seeking', 'touching', 'song', 'dwelling', 'beating', 'making', 'stroke', 'beginning', 'bold', 'scrutinizing', 'wig', 'saying', 'dancing', 'himself', 'coming', 'a', ';', 'among', 'shrill', 'wishing', 'sleeping', 'knowing', 'meeting', 'raise', 'lovely', 'stall', 'brink', 'wherein', 'chantilly', 'stiff', 'fearfully', 'sleep', 'skin', 'cat', 'young', 'dull', 'rough', 'doing', 'allow', 'vain', 'singular', 'madly', 'quietly', 'behold', 'hereupon', 'singularly', 'referring', 'saw', 'abruptly', 'shake', 'satin', 'cabin', 'strongly', 'betook', 'quitting', 'giving', 'notwithstanding', 'wrong', 'chiefly', 'tall', 'hitherto', 'safely', 'insisting', 'stupor', 'trifling', 'rigid', 'sad', 'pair', 'belonging', 'wisdom', 'stir', 'paintings', 'hurriedly', 'bolt', 'chief', 'strange', 'pfaall', 'strangely', 'strip', 'awful', 'attempting', 'fair', 'fairy', 'enjoying', 'pain', 'getting', 'sorrow', 'thinking', 'tone', 'earnestly', 'deadly', 'screw', 'lot', 'allowing', 'hit', 'ruin', 'likely', 'childish', 'break', 'kept', 'sinking', 'bearing', 'scythe', 'castle', 'sash', 'july', 'muslin', 'grin', 'drink', 'train', 'dreadful', 'where', 'calls', 'still', 'unto', 'freedom', 'chagrin', 'fairly', 'palazzo', 'shrank', 'tarpaulin', 'crossing', 'heels', 'female', 'blind', 'casting', 'burn', 'smoke', 'detecting', 'dropping', 'brings', 'gain', 'task', 'blew', 'accounting', 'beheld', 'scrap', 'child', 'pipe', 'freely', 'study', 'alarming', 'history', 'thorough', 'nostrils', 'drunk', 'wheels', 'parlor', 'tomb', 'quickly', 'gad', 'cask', 'reward', 'cape', 'change', 'gulf', 'gang', 'seldom', 'chimney', 'elbow', 'breathing', 'bas', 'bedloe', 'coat', 'malady', 'whose', 'glad', 'glass', 'shop', 'razor', 'staircase', 'taste', 'cap', 'stage', 'scrutiny', 'painful', 'cut', 'oak', 'buckle', 'dream', 'dreamy', 'shriek', 'metzengerstein', 'margin', 'lie', 'shown', 'carry', 'satellite', 'noise', 'eyelids', 'law', 'held', 'europe', 'setting', 'endeavor', 'echo', 'therein', 'jaws', 'behavior', 'screams', 'herself', 'fearful', 'blackwood', 'music', 'myself', 'finger', 'tongue', 'melody', 'health', 'thoroughly', 'lose', 'fat', 'blush', 'brief', 'holy', 'vulgar', 'preceding', 'mud', 'barrel', 'totally', 'footstep', 'pompey', 'slept', 'built', 'vague', 'sofa', 'zaire', 'amid', 'daily', 'gaze', 'awake', 'spoke', 'vehicle', 'steady', 'unquiet', 'pallor', 'whirlpool', 'drop', 'letting', 'hugh', 'breaking', 'arch', 'hearts', 'pallid', 'topics', 'brilliancy', 'hero', 'dwelt', 'grim', 'bottle', 'leaping', 'parallel', 'gait', 'took', 'hope', 'favorite', 'kind', 'basket', 'ström', 'hermann', 'hereditary', 'taking', 'canvas', 'swept', 'dreams', 'obtain', 'knife', 'rash', 'boldly', 'wife', 'lake', 'guide', 'frog', 'shrieks', 'too', 'plunge', 'cross', 'off', 'endeavoring', 'snuff', 'behind', 'burst', 'egypt', 'salt', 'lungs', 'safe', 'trunk', 'awaking', 'follows', 'justly', 'bank', 'reaching', 'fabric', 'whiskers', 'yield', 'volume', 'george', 'surprising', 'rat', 'risk', 'drama', 'shook', 'removing', 'books', 'bulk', 'wealth', 'casks', 'enjoy', 'deeply', 'causing', 'singing', 'vows', 'eagerly', 'also', 'opium', 'broke', 'aside', 'whisper', 'seeing', 'handkerchief', 'tapestry', 'playing', 'passage', 'living', 'across', 'somewhere', 'shield', 'seize', 'bore', 'story', 'clew', 'soleil', 'asleep', 'ran', 'visit', 'wings', 'exquisitely', 'poor', 'family', 'ligeia', 'sketch', 'approaching', 'shone', 'accordingly', 'believing', 'exquisite', 'melancholy', 'hurry', 'wrath', 'pulling', 'glancing', 'slang', 'barely', 'while', 'favor', 'graceful', 'grow', 'scrupulous', 'pillow', 'aloud', 'horse', 'rage', 'oxford', 'gale', 'dilemma', 'marvellous', 'brilliant', 'footsteps', 'flew', 'hill', 'legs', 'stronger', 'concerning', 'shudder', 'alarm', 'outrage', 'pendulum', 'glimpse', 'extra', 'worn', 'calm', 'ourang', 'h ...
# .:['journal', 'pest', 'demonstrate', 'deliberate', 'advantage', 'model', 'rotterdam', 'diddle', 'offer', 'besides', 'templeton', 'antiochus', 'lest', 'escape', 'nameless', 'dungeon', 'sign', 'easy', 'newspaper', 'relatives', 'define', 'diddler', 'signal', 'tempest', 'majesty', 'crimson', 'london', 'testimony', 'inside', 'antique', 'prodigies', 'idle', 'rule', 'newspapers', 'opportunity', 'people', 'scruple', 'ignorant', 'authority', 'worthy', 'arrant', 'miracle', 'axis', 'examine', 'voyage', 'decisive', 'reign', 'outrage', 'citizens', 'establish', 'earnest', 'despair', 'temple', 'merchant', 'baron', 'phenomenon', 'moss', 'physician', 'delirium', 'plan', 'premises', 'triumphant', 'precipice', 'anon', 'absurdity', 'orbit', 'complete', 'uneasy', 'courage', 'deny', 'cry', 'audacity', 'trifle', 'precipitate', 'mode', 'motive', 'legitimate', 'calamity', 'society', 'brewster', 'analysis', 'criticism', 'sunrise', 'astronomers', 'commerciel', 'capacity', 'match', 'telescope', 'inhabitants', 'axioms', 'symptoms', 'promises', 'literary', 'atrocity', 'master', 'triumph', 'sum', 'precincts', 'agreeable', 'policy', 'august', 'mare', 'philosophy', 'american', 'occupy', 'antennæ', 'try', 'grotesque', 'angels', 'makes', 'copy', 'demeanor', 'inquire', 'court', 'minister', 'work', 'tribe', 'jest', 'magician', 'school', 'empire', 'employ', 'venice', 'similar', 'regret', 'pole', 'delay', 'answer', 'kate', 'lunatic', 'delicate', 'eager', 'warrant', 'mantel', 'schools', 'mark', 'decay', 'comet', 'signs', 'circle', 'soleil', 'universe', 'agency', 'medium', 'common', 'ascendancy', 'accurate', 'rage', 'letters', 'magnetic', 'vehicle', 'marriage', 'unfortunate', 'together', 'anxiety', 'complex', 'accuracy', 'majestic', 'honest', 'penny', 'antiquity', 'scene', 'memory', 'suicide', 'author', 'purchase', 'apathy', 'spanish', 'glimpse', 'deposit', 'british', 'system', 'danger', 'affidavits', 'manoeuvre', 'edinburgh', 'america', 'modern', 'otherwise', 'charleston', 'magazine', 'alexander', 'universal', 'base', 'divine', 'sober', 'report', 'similarity', 'cognizant', 'superfluous', 'treatise', 'sort', 'moderate', 'physicians', 'french', 'works', 'unequivocal', 'monarch', 'style', 'delicacy', 'paper', 'acknowledge', 'des', 'organ', 'liberal', 'inquiries', 'desolate', 'peg', 'speech', 'estimate', 'bizarre', 'aunt', 'planet', 'immortality', 'afford', 'phenomena', 'vulgar', 'metzengerstein', 'parisian', 'meantime', 'orange', 'music', 'combat', 'ruffians', 'arrival', 'desperate', 'destiny', 'europe', 'ether', 'opportunities', 'keepers', 'oxford', 'metropolis', 'papers', 'judges', 'angel', 'supper', 'police', 'favorite', 'decease', 'academy', 'inquiry', 'courtesy', 'angry', 'propeller', 'bliss', 'emperor', 'trunk', 'ocean', 'port', 'illustrious', 'occur', 'bitter', 'guilty', 'maiden', 'sometimes', 'summer', 'portrait', 'philosophical', 'change', 'survey', 'quaint', 'admirable', 'opium', 'royal', 'scythe', 'epidaphne', 'pursuit', 'beast', 'atlantic', 'enigma', 'egypt', 'miserable', 'describe', 'girl', 'mortality', 'analogy', 'doctrines', 'epiphanes', 'marvellous', 'ourselves', 'favor', 'hesitate', 'ascend', 'humble', 'sooner', 'injury', 'vault', 'altogether', 'dilemma', 'perfume', 'perfumery', 'ghost', 'church', 'university', 'public', 'tragedy', 'apparatus', 'messrs', 'george', 'demon', 'anger', 'begins', 'wood', 'list', 'prodigious', 'summit', 'analogous', 'classical', 'insert', 'equivocal', 'council', 'comes', 'epoch', 'needless', 'bulk', 'anticipate', 'kind', 'treasure', 'mesmeric', 'met', 'vitality', 'attendants', 'date', 'arrive', 'particulars', 'sympathy', 'popular', 'worn', 'tenuity', 'ridiculous', 'x', 'castle', 'services', 'written', 'requisite', 'kempelen', 'delirious', 'elaborate', 'history', 'cabinet', 'soon', 'predominant', 'wilson', 'owner', 'brigadier', 'guess', 'hurry', 'landscape', 'scrupulous', 'unknown', 'extensive', 'humor', 'west', 'wont', 'masonry', 'stranger', 'judge', 'scrap', 'disgust', 'seaman', 'harmless', 'gothic', 'april', 'abandon', 'sa ...
# [';', 'sleep', 'freedom', 'stroke', 'chantilly', 'fearfully', 'dreadful', 'taste', 'footstep', 'glass', 'stiff', 'swept', 'vague', 'awful', 'palazzo', 'unquiet', 'dreamy', 'betook', 'unto', 'finger', 'gulf', 'beheld', 'screw', 'shriek', 'abruptly', 'slept', 'shrank', 'stupor', 'nostrils', 'burthen', 'whisper', 'seldom', 'burst', 'shrieks', 'brief', 'seize', 'raise', 'thoroughly', 'painful', 'blind', 'earnestly', 'stir', 'footsteps', 'shrill', 'shown', 'pair', 'dream', 'reward', 'wheels', 'muslin', 'risk', 'waker', 'lot', 'heels', 'shone', 'clew', 'childish', 'visit', 'hurriedly', 'quietly', 'whiskers', 'wherein', 'rash', 'razor', 'chief', 'jaws', 'pendulum', 'wept', 'built', 'pipe', 'task', 'gaze', 'sash', 'simultaneously', 'strip', 'lofoden', 'bas', 'kept', 'wealth', 'barrel', 'behavior', 'brilliancy', 'strongly', 'female', 'melody', 'casks', 'dreams', 'volume', 'sofa', 'freely', 'murmur', 'travelling', 'field', 'eleonora', 'calls', 'brink', 'bold', 'oak', 'blew', 'tomb', 'rigid', 'wisdom', 'diana', 'break', 'parlor', 'victim', 'fearful', 'leaden', 'law', 'scrutiny', 'zaire', 'burn', 'plunge', 'safely', 'deeply', 'screams', 'pain', 'bolt', 'ruin', 'canvas', 'elbow', 'ligeia', 'loathsome', 'fabric', 'chiefly', 'daily', 'avenue', 'search', 'july', 'shop', 'satellite', 'hitherto', 'tarpaulin', 'staircase', 'eyelids', 'whirlpool', 'grim', 'among', 'foam', 'paintings', 'hurricane', 'cabin', 'fairy', 'forbear', 'tone', 'oxford', 'eagerly', 'chimney', 'firmly', 'amid', 'louder', 'lovely', 'flew', 'lungs', 'dwelt', 'parallel', 'helseggen', 'solid', 'secret', 'sorrow', 'ocean', 'echo', 'cape', 'chagrin', 'luminous', 'rat', 'everywhere', 'stronger', 'thorough', 'deadly', 'tore', 'strange', 'singularly', 'metzengerstein', 'glare', 'dilemma', 'tapestry', 'bedloe', 'gorgeous', 'livid', 'blush', 'cat', 'mud', 'across', 'glad', 'crew', 'song', 'seas', 'ms', 'pallid', 'gad', 'brute', 'class', 'scythe', 'laws', 'harmony', 'grin', 'knife', 'pockets', 'castle', 'buckle', 'vessel', 'barrière', 'bore', 'margin', 'church', 'strong', 'cross', 'wave', 'berlifitzing', 'somewhere', 'brilliant', 'enjoy', 'vehicle', 'flesh', 'stage', 'shield', 'satin', 'child', 'alarm', 'basket', 'passage', 'likely', 'bulk', 'cabinet', 'lover', 'coat', 'wrath', 'heir', 'endeavors', 'scrutinized', 'skin', 'pallor', 'tongues', 'decay', 'vulgar', 'lunar', 'scrutinizing', 'favorite', 'creditors', 'frivolous', 'ourang', 'cask', 'chicken', 'arisen', 'fullest', 'shudder', 'depends', 'hereditary', 'moreover', 'enclosure', 'drunk', 'strangely', 'singular', 'wicker', 'emperor', 'glimpse', 'books', 'fairly', 'abyss', 'tube', 'visage', 'waist', 'hurry', 'pfaall', 'eustache', 'views', 'wherever', 'still', 'deposit', 'scrupulous', 'shake', 'melancholy', 'change', 'egypt', 'rare', 'hearts', 'inquiries', 'graceful', 'america', 'europe', 'gay', 'illimitable', 'slope', 'ström', 'carry', 'schools', 'grotesque', 'worn', 'maiden', 'orange', 'scrap', 'yells', 'tumultuous', 'behold', 'becoming', 'vain', 'warrant', 'solitude', 'lie', 'fierce', 'health', 'hesitate', 'clearly', 'drop', 'radiant', 'sweep', 'aloud', 'assuming', 'summit', 'epiphanes', 'dull', 'without', 'listen', 'george', 'smoke', 'customs', 'aside', 'list', 'vows', 'obtain', 'wig', 'rub', 'antennæ', 'pompey', 'opium', 'partook', 'horse', 'guesses', 'blows', 'was', 'grave', 'painting', 'loss', 'parisian', 'crime', 'sweeps', 'sad', 'epoch', 'vessels', 'shook', 'sockets', 'exquisite', 'lapse', 'longest', 'uneasy', 'philosophy', 'usher', 'manoeuvre', 'perpendicularly', 'bank', 'safe', 'empire', 'holy', 'salt', 'scratching', 'saw', 'ruffians', 'blackwood', 'granite', 'angry', 'marriage', 'luxury', 'axioms', 'papers', 'dismay', 'tarn', 'grow', 'where', 'penny', 'spot', 'set', 'tenant', 'also', 'verses', 'axis', 'accompanied', 'therein', 'valet', 'borough', 'banks', 'sovereign', 'steady', 'guide', 'shot', 'behind', 'gendarme', 'rudder', 'hereafter', 'accounting', 'music', 'bricks', 'awake', 'fresh', 'newspapers', 'dawn', 'symptoms', 'pa ...
# <class 'list'>
# 3003
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:2377: RuntimeWarning: invalid value encountered in true_divide
#   return (m / dist).astype(REAL)

# %%
mycolors = [i-i%(word_treshold+1) for i in range(len(all_similar_words))]
mycolors = ['red' if i == 0 else 'cyan' if i==1001 else 'green' for i in mycolors]
plt.figure(figsize=(20, 5))
plt.title('EAP punctuation clusters')
plt.scatter(p_comps[:, 0], p_comps[:, 1], c=mycolors,  s = frequency_of_words, alpha=0.4)

for word_names, x, y in zip(word_names, p_comps[:, 0], p_comps[:, 1]):
  if word_names in punctuation_in_mws:
     plt.annotate(word_names, xy=(x+0.06, y+0.03), xytext=(0, 0), textcoords='offset points', size = 50, bbox=dict(facecolor='None', edgecolor='black'))
plt.show()

# %% [markdown]
# ## HPL

# %%
word_treshold = 1000
just_keep_major_punct = True



hpl_ft_model = FastText.load_fasttext_format('hpl_ft_model.bin')

# first we check the punctuation assertion: which tokens are the most similar to exisiting punctuation?

for i in punctuation:
  print(i + ' exists: ' +str(i in hpl_ft_model.wv.vocab))
# and remove the ones that don't since we need at least one n-gram with it for comparison
punctuation_in_hpl = [i for i in punctuation if i in hpl_ft_model.wv.vocab]

if just_keep_major_punct:
  punctuation_in_hpl.remove('…')
  punctuation_in_hpl.remove("'")
  punctuation_in_hpl.remove(':')
  punctuation_in_hpl.remove('?')
  punctuation_in_hpl.remove('"')



semantically_similar_words = {words: [item[0] for item in hpl_ft_model.wv.most_similar([words], topn=word_treshold)] for words in punctuation_in_hpl}
for k,v in semantically_similar_words.items():
    print(k+":"+str(v))
all_similar_words = sum([[k] + v for k, v in semantically_similar_words.items()], [])
frequency_of_words = [hpl_ft_model.wv.vocab[i].count for i in all_similar_words]
# frequency_of_words = [i if i<100 else 100 for i in frequency_of_words ]

print(all_similar_words)
print(type(all_similar_words))
print(len(all_similar_words))

word_vectors = hpl_ft_model.wv[all_similar_words]

pca = PCA(n_components=2)

p_comps = pca.fit_transform(word_vectors)
#p_comps = TSNE(n_components=2, perplexity=10).fit_transform(word_vectors)

word_names = all_similar_words

# plt.figure(figsize=(18, 10))
# plt.scatter(p_comps[:, 0], p_comps[:, 1], c=[i-i%(word_treshold+1) for i in range(len(all_similar_words))], cmap='Set1', s = frequency_of_words, alpha=1)

# for word_names, x, y in zip(word_names, p_comps[:, 0], p_comps[:, 1]):
#   if word_names in punctuation_in_hpl:
#      plt.annotate(word_names, xy=(x+0.06, y+0.03), xytext=(0, 0), textcoords='offset points', size = 20, bbox=dict(facecolor='None', edgecolor='black'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
# ; exists: True
# , exists: True
# . exists: True
# " exists: True
# ! exists: False
# : exists: True
# ? exists: True
# ( exists: False
# - exists: False
# ' exists: True
# ) exists: False
# — exists: False
# … exists: True
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:2377: RuntimeWarning: invalid value encountered in true_divide
#   return (m / dist).astype(REAL)
# ;:['madly', 'responsible', 'vaguely', 'merely', 'dimly', 'sensible', 'conscious', 'appearance', 'dress', 'memorable', 'existence', 'remoteness', 'surely', 'possible', 'inaccessible', 'restlessly', 'fully', 'ice', 'entrance', 'generally', 'subtly', 'conceivable', 'barely', 'unconscious', 'fairly', 'illusion', 'equally', 'progress', 'vague', 'invisible', 'dimensions', 'easily', 'spectral', 'consciousness', 'july', 'impressions', 'suggestions', 'restless', 'ghastly', 'contents', 'peculiarly', 'constant', 'confusion', 'tense', 'event', 'revolution', 'performed', 'virtually', 'unless', 'recent', 'possession', 'prevent', 'unspeakable', 'proportions', 'connexion', 'science', 'description', 'cautious', 'mental', 'apprehension', 'element', 'inexplicable', 'dimensional', 'considerable', 'delusion', 'press', 'foundations', 'oddly', 'formerly', 'vainly', 'impossible', 'substance', 'succession', 'directly', 'scarcely', 'formless', 'suitable', 'extent', 'evidence', 'horror', 'rational', 'usually', 'civilisation', 'moments', 'were', 'unutterable', 'reflections', 'glance', 'daily', 'occasionally', 'general', 'advance', 'deadly', 'madness', 'constantly', 'apartment', 'repulsion', 'legions', 'remains', 'disturbed', 'recollections', 'utterly', 'concealed', 'particularly', 'once', 'indescribable', 'rent', 'dance', 'previously', 'version', 'count', 'venture', 'inch', 'excitement', 'influence', 'whose', 'dense', 'unnamable', 'clearly', 'interior', 'course', 'wholly', 'proportion', 'fascination', 'absence', 'inconceivable', 'electrical', 'associations', 'conditions', 'first', 'remarkable', 'scaly', 'dimension', 'generations', 'ugly', 'unimaginable', 'frantically', 'hysterical', 'disappeared', 'vice', 'radiance', 'gradually', 'eventually', 'dismal', 'strangeness', 'medical', 'ignorance', 'conversation', 'screams', 'feeble', 'ancestry', 'entirely', 'fancy', 'ancestral', 'regions', 'unendurable', 'fashion', 'destroyed', 'convinced', 'occasional', 'discovered', 'considered', 'badly', 'examination', 'actually', 'preservation', 'habitation', 'frame', 'gentle', 'suddenly', 'determined', 'providence', 'unnatural', 'emotions', 'subtle', 'capable', 'whence', 'commenced', 'prodigious', 'lately', 'concluded', 'french', 'exaggerated', 'terrified', 'reputation', 'pronounced', 'discussed', 'dreams', 'unaccountable', 'repeated', 'frightful', 'mostly', 'inevitable', 'visitor', 'image', 'partitions', 'information', 'possessed', 'perilous', 'subsequently', 'furtively', 'peace', 'unbearable', 'cohort', 'spectacled', 'wildly', 'reanimated', 'strangers', 'noxious', 'imagined', 'speculation', 'suggestion', 'hopelessly', 'presumably', 'fame', 'conjectures', 'became', 'obviously', 'unusual', 'sort', 'encountered', 'screamed', 'crazily', 'vegetation', 'appear', 'experiment', 'fresh', 'scale', 'recorded', 'future', 'connect', 'violence', 'provided', 'interest', 'physical', 'country', 'fragments', 'spread', 'perished', 'previous', 'disordered', 'remarked', 'occasion', 'eagerness', 'incidents', 'position', 'visit', 'associated', 'promised', 'hideously', 'nervously', 'brought', 'college', 'brainless', 'vividness', 'thoroughly', 'universe', 'sole', 'unmistakable', 'profoundly', 'inexplicably', 'conception', 'rough', 'newly', 'perceived', 'scream', 'questioned', 'legion', 'horrors', 'strange', 'host', 'plainly', 'infinitely', 'research', 'apparent', 'court', 'terror', 'attracted', 'scientist', 'whole', 'regarded', 'immediately', 'designs', 'scattered', 'familiar', 'immense', 'expression', 'evidently', 'rapidly', 'courage', 'decadent', 'incredible', 'disappearance', 'separated', 'paralysed', 'temperament', 'desperation', 'accident', 'organic', 'vivid', 'considerably', 'bafflement', 'investigation', 'came', 'forest', 'often', 'example', 'instruments', 'distinguish', 'source', 'exceedingly', 'apparently', 'superintendent', 'natural', 'disease', 'directions', 'processes', 'sickly', 'damnable', 'treated', 'intelligence', 'obvious', 'forms', 'papers', 'displayed', 'revealed', 'resemblan ...
# ,:['sat', 'afraid', 'when', 'wish', 'dropped', 'glad', 'shoulder', 'whisper', 'seven', 'catch', 'learn', 'therein', 'somehow', 'accompany', 'poor', 'shudder', 'eleven', 'major', 'theory', 'change', 'ran', 'awe', 'spoke', 'worry', 'awake', 'revenge', 'laugh', 'wanted', 'merciful', 'sordid', 'company', 'however', 'myself', 'asleep', 'thirty', 'become', 'kindly', 'lee', 'wonders', 'sally', 'then', 'truly', 'leave', 'mercy', 'lethal', 'teacher', 'taught', 'shot', 'lean', 'caught', 'explorer', 'simply', 'johansen', 'doubt', 'these', 'somewhat', 'given', 'word', 'meant', 'thunder', 'mask', 'third', 'sane', 'phenomena', 'butcher', 'faithful', 'sabbat', 'altogether', 'sailor', 'survive', 'joe', 'fearful', 'therefore', 'speech', 'sailors', 'convey', 'hateful', 'goddess', 'zann', 'gentleman', 'revolver', 'cannibal', 'remain', 'daughter', 'save', 'methods', 'weaker', 'without', 'although', 'because', 'evil', 'shake', 'workmanship', 'explore', 'manner', 'bad', 'speak', 'muñoz', 'klenze', 'worn', 'davis', 'ann', 'heaved', 'someone', 'danger', 'dunwich', 'shutter', 'prayer', 'piece', 'permit', 'purpose', 'taken', 'words', 'thereafter', 'refinery', 'mathematics', 'forget', 'held', 'who', 'birch', 'gruesome', 'pray', 'servant', 'warren', 'heeded', 'positive', 'die', 'laughter', 'saw', 'whiskey', 'tread', 'shoot', 'second', 'extract', 'nose', 'sona', 'thus', 'herbert', 'sank', 'secret', 'awesome', 'hats', 'cause', 'few', 'harris', 'william', 'survivor', 'only', 'dogs', 'serve', 'elsewhere', 'nyarlathotep', 'november', 'ghouls', 'tragedy', 'nyl', 'abdul', 'knowledge', 'relief', 'him', 'aspect', 'cousin', 'aira', 'to', 'curtis', 'muddy', 'quasi', 'now', 'african', 'triumph', 'oil', 'italian', 'worse', 'exact', 'self', 'today', 'sail', 'sheds', 'describe', 'leader', 'lived', 'likewise', 'further', 'sunday', 'forever', 'some', 'jewellery', 'fearsome', 'task', 'urn', 'wilcox', 'myth', 'match', 'behold', 'wore', 'gilman', 'type', 'already', 'produce', 'myths', 'museum', 'wonderful', 'text', 'careful', 'tale', 'squire', 'yacht', 'mad', 'fact', 'souls', 'expectancy', 'fenner', 'canvas', 'congo', 'pursuit', 'dolphins', 'amulet', 'whither', 'inhuman', 'olive', 'how', 'same', 'clothing', 'woman', 'deep', 'imagine', 'poet', 'avid', 'cats', 'worship', 'relative', 'clean', 'explain', 'called', 'unlike', 'soul', 'safety', 'refusal', 'eager', 'quiet', 'shook', 'turn', 'hot', 'trip', 'habitual', 'helpless', 'sorcier', 'clatter', 'everyone', 'seldom', 'american', 'lost', 'brother', 'keziah', 'elder', 'minute', 'began', 'perhaps', 'september', 'paid', 'difficult', 'trail', 'number', 'shaped', 'proper', 'august', 'timber', 'titan', 'undertaker', 'asylum', 'remnants', 'albany', 'foot', 'primitive', 'season', 'pretty', 'ibid', 'physician', 'fathom', 'certain', 'honour', 'transom', 'special', 'sleep', 'am', 'specimen', 'handsome', 'funny', 'ethereal', 'shiver', 'quest', 'powder', 'telephone', 'randolph', 'feverish', 'habit', 'care', 'swore', 'wherein', 'songs', 'goatish', 'character', 'likely', 'mason', 'commercial', 'german', 'move', 'pit', 'us', 'supposed', 'overcome', 'active', 'cot', 'ghoulish', 'snow', 'there', 'seas', 'moan', 'utter', 'halsey', 'czanek', 'more', 'day', 'bugs', 'wear', 'artificial', 'difficulty', 'latter', 'cathuria', 'find', 'rays', 'world', 'sepulchre', 'imaginative', 'goal', 'coffin', 'morgan', 'mistake', 'trunk', 'many', 'answer', 'idea', 'farther', 'native', 'means', 'pitiful', 'link', 'guessed', 'just', 'sometimes', 'data', 'return', 'settle', 'post', 'deeper', 'sleeper', 'complex', 'gossip', 'comte', 'every', 'friends', 'comes', 'hamlet', 'english', 'quarters', 'rare', 'worlds', 'spells', 'frye', 'wheel', 'themselves', 'work', 'impulse', 'common', 'extraordinary', 'grandson', 'made', 'bizarre', 'curse', 'home', 'pursue', 'michel', 'supply', 'clapham', 'marshy', 'october', 'nevertheless', 'worshipped', 'mankind', 'devoid', 'williams', 'liquor', 'arab', 'noisome', 'shaven', 'bygone', 'copy', 'fust', 'shelter', 'hatheg', 'wise', 'note', 'po ...
# .:['england', 'dead', 'brain', 'bite', 'item', 'husband', 'betwixt', 'latin', 'english', 'puritan', 'lives', 'debris', 'rumour', 'tore', 'anxiety', 'shapeless', 'swarthy', 'uncouth', 'empty', 'own', 'escape', 'seat', 'pieces', 'prints', 'birds', 'sefton', 'foreign', 'robe', 'rhoby', 'score', 'ultimate', 'solemn', 'wire', 'market', 'robert', 'bizarre', 'plan', 'lips', 'portuguese', 'custom', 'travellers', 'kalends', 'slater', 'split', 'comes', 'bony', 'symbol', 'guardian', 'foetid', 'beryl', 'ibidus', 'separate', 'ib', 'february', 'faith', 'loathsome', 'data', 'aylesbury', 'manuxet', 'morgan', 'vain', 'artists', 'frye', 'command', 'sit', 'nargai', 'sepulchre', 'clothes', 'masonry', 'smith', 'bulk', 'changes', 'ipswich', 'crucifix', 'arab', 'tail', 'rhythm', 'moreover', 'michel', 'trace', 'system', 'dug', 'arm', 'sydney', 'clapham', 'holds', 'mnar', 'people', 'choynski', 'admiralty', 'duty', 'songs', 'mouldy', 'clerk', 'drove', 'mark', 'hints', 'field', 'weeks', 'telescope', 'seas', 'fungi', 'secrets', 'travel', 'williams', 'hellish', 'sardonic', 'signs', 'teeth', 'owner', 'marshes', 'george', 'georgian', 'cosmos', 'seldom', 'libo', 'motor', 'birth', 'headquarters', 'phantasy', 'wounds', 'fruit', 'level', 'bench', 'witchcraft', 'epidemic', 'torn', 'liquor', 'pursue', 'dank', 'narrative', 'aloud', 'childhood', 'later', 'bear', 'revellers', 'minds', 'splendid', 'aldebaran', 'tenants', 'shrieks', 'gulfs', 'bygone', 'ordinary', 'hamlet', 'theories', 'dizzy', 'newburyport', 'shots', 'albany', 'randolph', 'massive', 'czanek', 'yards', 'chemicals', 'relatives', 'poison', 'harbour', 'one', 'magnitude', 'keziah', 'fur', 'curse', 'magic', 'brief', 'oak', 'busy', 'crazy', 'hotel', 'lore', 'summit', 'idea', 'africa', 'afar', 'american', 'bugs', 'madhouse', 'always', 'made', 'type', 'kla', 'bird', 'marks', 'vessel', 'sometimes', 'army', 'hue', 'appleton', 'club', 'episode', 'also', 'silva', 'public', 'devoid', 'ghoulish', 'physician', 'chant', 'u', 'power', 'gruesome', 'clear', 'bus', 'swore', 'articulate', 'asylum', 'handsome', 'childish', 'rain', 'myths', 'natives', 'oonai', 'size', 'worthy', 'spirit', 'pretty', 'burn', 'weedy', 'dumb', 'society', 'secure', 'details', 'moan', 'victim', 'extraordinary', 'more', 'sunday', 'amulet', 'paris', 'cathuria', 'drive', 'landlady', 'quarters', 'delay', 'deep', 'benefit', 'lavinia', 'unlike', 'paper', 'text', 'sun', 'school', 'ideas', 'tiara', 'tissue', 'barzai', 'osborn', 'tombs', 'manuscript', 'shelves', 'array', 'clatter', 'festival', 'break', 'hold', 'domes', 'master', 'olney', 'cool', 'player', 'silver', 'number', 'worlds', 'poet', 'ape', 'heavily', 'ocean', 'negro', 'gorgeous', 'square', 'fiendish', 'easy', 'ear', 'primitive', 'sorcier', 'transom', 'chaos', 'curtis', 'april', 'feverish', 'settle', 'cattle', 'powerful', 'shaky', 'abroad', 'barn', 'disorder', 'tongue', 'thick', 'mate', 'ooth', 'letters', 'mistaken', 'lain', 'delirium', 'musty', 'denys', 'older', 'awesome', 'elwood', 'copy', 'memories', 'italian', 'september', 'ships', 'nightmare', 'ricci', 'few', 'makes', 'june', 'shelter', 'shrill', 'character', 'leader', 'fields', 'best', 'affair', 'caverns', 'titan', 'drugs', 'child', 'certain', 'clean', 'scholar', 'cousin', 'bend', 'legends', 'squalor', 'museum', 'difficulty', 'poets', 'judge', 'spells', 'muscular', 'pride', 'paid', 'antiquarian', 'bade', 'shiver', 'dolphins', 'atmosphere', 'whippoorwills', 'series', 'honour', 'furtive', 'helpless', 'pause', 'rush', 'effort', 'trail', 'squalid', 'behold', 'shops', 'dombrowski', 'william', 'eternal', 'quasi', 'already', 'four', 'fear', 'victims', 'remnants', 'pleasant', 'myth', 'inhuman', 'journey', 'does', 'avid', 'inhabitants', 'artificial', 'safety', 'cult', 'basalt', 'nyarlathotep', 'shaven', 'artist', 'prisoners', 'muddy', 'hieroglyphics', 'wilder', 'guard', 'latter', 'business', 'machine', 'wanderers', 'overcome', 'august', 'whine', 'bottom', 'sailors', 'shaft', 'himself', 'weaker', 'nyl', 'pitiful', 'sharply', 'tarry', 'heterogeneous', ' ...
# [';', 'madly', 'responsible', 'vaguely', 'merely', 'dimly', 'sensible', 'conscious', 'appearance', 'dress', 'memorable', 'existence', 'remoteness', 'surely', 'possible', 'inaccessible', 'restlessly', 'fully', 'ice', 'entrance', 'generally', 'subtly', 'conceivable', 'barely', 'unconscious', 'fairly', 'illusion', 'equally', 'progress', 'vague', 'invisible', 'dimensions', 'easily', 'spectral', 'consciousness', 'july', 'impressions', 'suggestions', 'restless', 'ghastly', 'contents', 'peculiarly', 'constant', 'confusion', 'tense', 'event', 'revolution', 'performed', 'virtually', 'unless', 'recent', 'possession', 'prevent', 'unspeakable', 'proportions', 'connexion', 'science', 'description', 'cautious', 'mental', 'apprehension', 'element', 'inexplicable', 'dimensional', 'considerable', 'delusion', 'press', 'foundations', 'oddly', 'formerly', 'vainly', 'impossible', 'substance', 'succession', 'directly', 'scarcely', 'formless', 'suitable', 'extent', 'evidence', 'horror', 'rational', 'usually', 'civilisation', 'moments', 'were', 'unutterable', 'reflections', 'glance', 'daily', 'occasionally', 'general', 'advance', 'deadly', 'madness', 'constantly', 'apartment', 'repulsion', 'legions', 'remains', 'disturbed', 'recollections', 'utterly', 'concealed', 'particularly', 'once', 'indescribable', 'rent', 'dance', 'previously', 'version', 'count', 'venture', 'inch', 'excitement', 'influence', 'whose', 'dense', 'unnamable', 'clearly', 'interior', 'course', 'wholly', 'proportion', 'fascination', 'absence', 'inconceivable', 'electrical', 'associations', 'conditions', 'first', 'remarkable', 'scaly', 'dimension', 'generations', 'ugly', 'unimaginable', 'frantically', 'hysterical', 'disappeared', 'vice', 'radiance', 'gradually', 'eventually', 'dismal', 'strangeness', 'medical', 'ignorance', 'conversation', 'screams', 'feeble', 'ancestry', 'entirely', 'fancy', 'ancestral', 'regions', 'unendurable', 'fashion', 'destroyed', 'convinced', 'occasional', 'discovered', 'considered', 'badly', 'examination', 'actually', 'preservation', 'habitation', 'frame', 'gentle', 'suddenly', 'determined', 'providence', 'unnatural', 'emotions', 'subtle', 'capable', 'whence', 'commenced', 'prodigious', 'lately', 'concluded', 'french', 'exaggerated', 'terrified', 'reputation', 'pronounced', 'discussed', 'dreams', 'unaccountable', 'repeated', 'frightful', 'mostly', 'inevitable', 'visitor', 'image', 'partitions', 'information', 'possessed', 'perilous', 'subsequently', 'furtively', 'peace', 'unbearable', 'cohort', 'spectacled', 'wildly', 'reanimated', 'strangers', 'noxious', 'imagined', 'speculation', 'suggestion', 'hopelessly', 'presumably', 'fame', 'conjectures', 'became', 'obviously', 'unusual', 'sort', 'encountered', 'screamed', 'crazily', 'vegetation', 'appear', 'experiment', 'fresh', 'scale', 'recorded', 'future', 'connect', 'violence', 'provided', 'interest', 'physical', 'country', 'fragments', 'spread', 'perished', 'previous', 'disordered', 'remarked', 'occasion', 'eagerness', 'incidents', 'position', 'visit', 'associated', 'promised', 'hideously', 'nervously', 'brought', 'college', 'brainless', 'vividness', 'thoroughly', 'universe', 'sole', 'unmistakable', 'profoundly', 'inexplicably', 'conception', 'rough', 'newly', 'perceived', 'scream', 'questioned', 'legion', 'horrors', 'strange', 'host', 'plainly', 'infinitely', 'research', 'apparent', 'court', 'terror', 'attracted', 'scientist', 'whole', 'regarded', 'immediately', 'designs', 'scattered', 'familiar', 'immense', 'expression', 'evidently', 'rapidly', 'courage', 'decadent', 'incredible', 'disappearance', 'separated', 'paralysed', 'temperament', 'desperation', 'accident', 'organic', 'vivid', 'considerably', 'bafflement', 'investigation', 'came', 'forest', 'often', 'example', 'instruments', 'distinguish', 'source', 'exceedingly', 'apparently', 'superintendent', 'natural', 'disease', 'directions', 'processes', 'sickly', 'damnable', 'treated', 'intelligence', 'obvious', 'forms', 'papers', 'displayed', 'revealed', 'resemb ...
# <class 'list'>
# 3003

# %%
mycolors = [i-i%(word_treshold+1) for i in range(len(all_similar_words))]
mycolors = ['red' if i == 0 else 'cyan' if i==1001 else 'green' for i in mycolors]
plt.figure(figsize=(20, 5))
plt.title('HPL punctuation clusters')
plt.scatter(p_comps[:, 0], p_comps[:, 1], c=mycolors,  s = frequency_of_words, alpha=0.4)

for word_names, x, y in zip(word_names, p_comps[:, 0], p_comps[:, 1]):
  if word_names in punctuation_in_mws:
     plt.annotate(word_names, xy=(x+0.06, y+0.03), xytext=(0, 0), textcoords='offset points', size = 50, bbox=dict(facecolor='None', edgecolor='black'))
plt.show()
